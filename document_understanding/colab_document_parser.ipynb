# %% [markdown]
# # Survey Plan AI - Document Understanding
#
# This notebook runs the Document Understanding pipeline using the Donut model. It expects a JSON file containing bounding box detections from the YOLO inference step.

# %%
# 1. Mount Google Drive (Data & Results)
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Deploy Code (Git Clone/Pull)
import os
import shutil

REPO_URL = "https://github.com/14jadon14/survey-plan-AI"
REPO_NAME = REPO_URL.split("/")[-1].replace(".git", "")
CODE_DIR = f"/content/{REPO_NAME}"

if os.path.exists(CODE_DIR):
    print("[INFO] Updating code...")
    # !cd "{CODE_DIR}" && git pull
else:
    print("[INFO] Cloning repository...")
    # !git clone "{REPO_URL}"

print(f"[SUCCESS] Code deployed to: {CODE_DIR}")

# %%
# 3. Setup Environment & Data
# Install dependencies from the document_understanding module
# !pip install -r "{CODE_DIR}/document_understanding/requirements.txt"

# Prepare Data (copy zip from Drive -> Local VM)
# This ensures images referenced in the JSON (e.g., /content/custom_data/...) exist
DRIVE_ROOT = "/content/drive/MyDrive"
POSSIBLE_DATA_PATHS = [
    f"{DRIVE_ROOT}/SurveyPlan AI/data.zip",
    f"{DRIVE_ROOT}/data.zip"
]

DATA_ZIP = None
for p in POSSIBLE_DATA_PATHS:
    if os.path.exists(p):
        DATA_ZIP = p
        break

if DATA_ZIP:
    # Unzip to /content/data to match the paths likely present in the JSON
    # (assuming JSON was generated with paths like /content/data/validation/...)
    IGNORE_DIR = "/content/data"
    if not os.path.exists(IGNORE_DIR):
        print(f"[INFO] Found data at {DATA_ZIP}. Unzipping to {IGNORE_DIR}...")
        # !unzip -q -o "{DATA_ZIP}" -d "{IGNORE_DIR}"
    else:
        print("[SUCCESS] Data likely ready (folder exists).")
else:
    print("[WARN] Warning: data.zip not found in Drive. Ensure it is in 'SurveyPlan AI' folder or Root.")

# %%
# 4. Locate YOLO Inference Output (JSON)
import glob

# Define potential paths where the YOLO inference might have saved the JSON
# Adjust strictly if you have a specific folder structure in Drive
DRIVE_ROOT = "/content/drive/MyDrive"
SEARCH_PATHS = [
    f"{DRIVE_ROOT}/crop_parameters.json",
    f"{DRIVE_ROOT}/SurveyPlan AI/crop_parameters.json",
    f"{DRIVE_ROOT}/SurveyPlan/crop_parameters.json",
    f"{DRIVE_ROOT}/**/crop_parameters.json"
]

json_path = None
print("[INFO] Searching for 'crop_parameters.json' in Drive...")

for path_pattern in SEARCH_PATHS:
    matches = glob.glob(path_pattern, recursive=True)
    if matches:
        json_path = matches[0]
        break

if json_path:
    print(f"[SUCCESS] Found JSON file at: {json_path}")
else:
    print("[WARN] JSON file not found automatically. Please specify the path manually below.")
    # json_path = "/content/drive/MyDrive/path/to/crop_parameters.json"

# %%
# 5. Run Document Parsing Pipeline
# Run directly in kernel (not via !python) so that plt.show() works inline

import sys
sys.path.insert(0, f"{CODE_DIR}/document_understanding")

if json_path and os.path.exists(json_path):
    print(f"[INFO] Running document parser on {json_path}...")
    import importlib
    
    # Reload the pipeline module first so it picks up the new crop-and-rotate math
    import pipeline
    importlib.reload(pipeline)
    
    # Reload the runner
    import run_on_image
    importlib.reload(run_on_image)
    
    run_on_image.run_custom(json_path=json_path)
    print("[SUCCESS] Processing complete.")
else:
    print("[ERROR] Cannot run pipeline: JSON path is invalid or file does not exist.")
